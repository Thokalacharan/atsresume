# %% [markdown]
# <a href="https://colab.research.google.com/github/Thokalacharan/atsresume/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install PyPDF2
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.6/232.6 kB 3.2 MB/s eta 0:00:00
# ...

# %%
import PyPDF2

def extract_text_from_pdf(pdf_path):
    """
    Extracts text from all pages of a PDF file.
    """
    extracted_text = ""

    with open(pdf_path, "rb") as file:
        reader = PyPDF2.PdfReader(file)

        for page in reader.pages:
            page_text = page.extract_text()
            if page_text:
                extracted_text += page_text

    return extracted_text

# %%
pdf_path = "charan (1).pdf"
text = extract_text_from_pdf(pdf_path)

print(text)
# Out:
# Thokala Charan
# Eluru, India|thokalacharan68@gmail.com|+91 9908957368
# linkedin.com/in/ThokalaCharan|github.com/thokalacharan
# Executive Summary
# Computer Science student with hands-on experience inweb application developmentandresponsive UI
# design. Delivered real-world projects that improved usability and layout consistency by30%while
# implementing secure user authentication workflows.
# Technical Skills
# Programming Languages:Java, Python, JavaScript
# Web Technologies:HTML5, CSS3, Responsive Web Design
# Backend & Cloud:Firebase Authentication, Firestore Database (NoSQL)
# Developer Tools:Git, GitHub, VS Code
# Core Knowledge:Authentication Workflows, CRUD Operations, Database Fundamentals, DBMS, Data Structures
# and Algorithms, Problem Solving
# Experience
# Web Development InternDec 2024 – Feb 2025
# CoderOne
# –Developed responsive web pages using HTML, CSS, and JavaScript, improving usability and layout consistency by
# 30%.
# ...

# %%
from google import genai
client = genai.Client(api_key="AIzaSyAZhMOkKwGHaK8G1v6yBwl1vSRSt4Rr0kg")

# %%
response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=f'here is the context:{text} question: give rate about my resume 100'
)

print(response.text)
# Out:
# Okay, Charan, your resume has a lot of excellent qualities, especially the *quantification* you've used throughout. However, there's a critical issue that needs immediate attention.
#
# Let's break it down:
#
# ---
#
# **Overall Rating: 65/100**
#
# **Why 65?**
#
# **Strengths (Excellent!):**
# 1.  **Quantification is Outstanding:** You've done an incredible job of adding numbers and percentages everywhere (30%, 40%, 100+ records, 35% mobile usability, 50+ simulated users, 8.76 CGPA, 93.6%, 3+ hackathons, 50+ teams). This is exactly what recruiters look for and makes your impact clear.
# 2.  **Strong Executive Summary:** Concise, impactful, and immediately highlights key skills and achievements.
# 3.  **Relevant Technical Skills:** A good mix of programming languages, web technologies, backend/cloud tools, and fundamental CS knowledge.
# ...

# %%
def resume_parser(input):
  prompt=f"""
  your resume parser
  Extract:
  -Executive Summary
  -Skills
  -Education
  -Tools & Techonolgies
  -Experience Summary

  Resume:
  {input}
  return in bullet points
  """
  response = client.models.generate_content(
          model = "gemini-2.5-flash",
          contents = prompt
  )
  return response.text

charan = resume_parser(text)
print(charan)
# Out:
# Here's the extracted information in bullet points:
#
# *   **Executive Summary**
#     *   Computer Science student with hands-on experience in web application development and responsive UI design.
#     *   Delivered real-world projects that improved usability and layout consistency by 30% while implementing secure user authentication workflows.
#
# *   **Skills**
#     *   **Programming Languages**: Java, Python, JavaScript
#     *   **Web Technologies**: HTML5, CSS3, Responsive Web Design
#     *   **Backend & Cloud**: Firebase Authentication, Firestore Database (NoSQL)
#     *   **Core Knowledge**: Authentication Workflows, CRUD Operations, Database Fundamentals, DBMS, Data Structures and Algorithms, Problem Solving
#
# *   **Education**
#     *   **Vishnu Institute of Technology, Bhimavaram (2023 – 2027)**: B.Tech in Computer Science and Engineering (CGPA: 8.76/10)
#     *   **Narayana Junior College, Vijayawada (2021 – 2023)**: Intermediate (Percentage: 93.6%)
# ...

# %%
def jobDescription(output):
  prompt=f"""
  your jobDescription parser
  Extract:
   -Skills
   -Responsebilities
   -Qualifications

   Job Description:
   {output}
  return in bullet points
  """

  response = client.models.generate_content(
      model = "gemini-2.5-flash",
      contents = prompt
  )
  print(response.text)
  return response.text

 # Resume parsing
charann = jobDescription(text)
print("===== PARSED RESUME =====")
print(charann)
# Out:
# Here's the extracted information from the provided resume:
#
# ### Skills
#
# *   **Programming Languages:** Java, Python, JavaScript
# *   **Web Technologies:** HTML5, CSS3, Responsive Web Design, React, Tailwind CSS
# *   **Backend & Cloud:** Firebase Authentication, Firestore Database (NoSQL), MongoDB
# *   **Developer Tools:** Git, GitHub, VS Code
# *   **Core Knowledge:** Authentication Workflows, CRUD Operations, Database Fundamentals, DBMS, Data Structures and Algorithms, Problem Solving
# *   **AI/ML Concepts:** Generative AI, LLM Basics, Prompt Engineering, API-based LLM Usage, NLP Preprocessing, Embeddings for Semantic Similarity
# *   **General Skills:** Web Application Development, Responsive UI Design, Secure User Authentication, Data Storage, Full-Stack Development, Role-Based Access
#
# ### Responsibilities
#
# *   Developed responsive web pages using HTML, CSS, and JavaScript.
# *   Improved usability and layout consistency by 30%.
# ...

# %%
def ats_match(parsed_resume, parsed_jd):
    prompt = f"""
You are an Applicant Tracking System.

Compare the resume and job description.

Resume:
{parsed_resume}

Job Description:
{parsed_jd}

Provide:
1. Match percentage (0-100)
2. Matching skills
3. Missing skills
4. Strengths
5. Improvement suggestions
"""
    response = client.models.generate_content(
        model="gemini-2.5-flash",
        contents=prompt
    )
    return response.text

# %%
ats_result = ats_match(charan, charann)

print("===== ATS MATCH RESULT =====")
print(ats_result)
# Out:
# ===== ATS MATCH RESULT =====
# As an Applicant Tracking System, I have analyzed the provided resume against the job description.
#
# ---
#
# ### 1. Match Percentage
# **68%**
#
# ---
#
# ### 2. Matching Skills
#
# The resume demonstrates strong alignment with the technical and knowledge requirements of the job description.
#
# *   **Programming Languages:** Java, Python, JavaScript
# *   **Web Technologies:** HTML5, CSS3, Responsive Web Design, React, Tailwind CSS
# *   **Backend & Cloud:** Firebase Authentication, Firestore Database (NoSQL), MongoDB
# *   **Developer Tools:** Git, GitHub, VS Code
# *   **Core Knowledge:** Authentication Workflows, CRUD Operations, Database Fundamentals, DBMS, Data Structures and Algorithms, Problem Solving
# *   **AI/ML Concepts:** Generative AI, LLM Basics, Prompt Engineering, API-based LLM Usage, NLP Preprocessing, Embeddings for Semantic Similarity (demonstrated through Generative AI Trainee experience)
# ...
